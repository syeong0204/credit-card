# %%
import pandas as pd

# %%
df = pd.read_csv('application_record.csv')

# %%
df
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008805           M            Y               Y             0
# 2       5008806           M            Y               Y             0
# 3       5008808           F            N               Y             0
# 4       5008809           F            N               Y             0
# ...         ...         ...          ...             ...           ...
# 438552  6840104           M            N               Y             0
# 438553  6840222           F            N               N             0
# 438554  6841878           F            N               N             0
# 438555  6842765           F            N               Y             0
# 438556  6842885           F            N               Y             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 438557 entries, 0 to 438556
# Data columns (total 18 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ID                   438557 non-null  int64
#  1   CODE_GENDER          438557 non-null  object
#  2   FLAG_OWN_CAR         438557 non-null  object
#  3   FLAG_OWN_REALTY      438557 non-null  object
#  4   CNT_CHILDREN         438557 non-null  int64
#  5   AMT_INCOME_TOTAL     438557 non-null  float64
#  6   NAME_INCOME_TYPE     438557 non-null  object
#  7   NAME_EDUCATION_TYPE  438557 non-null  object
#  8   NAME_FAMILY_STATUS   438557 non-null  object
#  9   NAME_HOUSING_TYPE    438557 non-null  object
#  10  DAYS_BIRTH           438557 non-null  int64
#  11  DAYS_EMPLOYED        438557 non-null  int64
#  12  FLAG_MOBIL           438557 non-null  int64
#  13  FLAG_WORK_PHONE      438557 non-null  int64
#  14  FLAG_PHONE           438557 non-null  int64
# ...

# %%
df
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008805           M            Y               Y             0
# 2       5008806           M            Y               Y             0
# 3       5008808           F            N               Y             0
# 4       5008809           F            N               Y             0
# ...         ...         ...          ...             ...           ...
# 438552  6840104           M            N               Y             0
# 438553  6840222           F            N               N             0
# 438554  6841878           F            N               N             0
# 438555  6842765           F            N               Y             0
# 438556  6842885           F            N               Y             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
pd.read_csv('credit_record.csv').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 3 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   ID              1048575 non-null  int64
#  1   MONTHS_BALANCE  1048575 non-null  int64
#  2   STATUS          1048575 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 24.0+ MB

# %%
df_dummy = pd.get_dummies(df)

# %%
df_dummy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 438557 entries, 0 to 438556
# Data columns (total 55 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   ID                                                 438557 non-null  int64
#  1   CNT_CHILDREN                                       438557 non-null  int64
#  2   AMT_INCOME_TOTAL                                   438557 non-null  float64
#  3   DAYS_BIRTH                                         438557 non-null  int64
#  4   DAYS_EMPLOYED                                      438557 non-null  int64
#  5   FLAG_MOBIL                                         438557 non-null  int64
#  6   FLAG_WORK_PHONE                                    438557 non-null  int64
#  7   FLAG_PHONE                                         438557 non-null  int64
# ...

# %%
len(df['OCCUPATION_TYPE'].value_counts())
# Out:
# 18

# %%
df_dummy.to_csv("app_record_ml.csv")

# %%
pd.read_csv("app_record_ml.csv")
# Out:
#         Unnamed: 0       ID  CNT_CHILDREN  AMT_INCOME_TOTAL  DAYS_BIRTH  \
# 0                0  5008804             0          427500.0      -12005
# 1                1  5008805             0          427500.0      -12005
# 2                2  5008806             0          112500.0      -21474
# 3                3  5008808             0          270000.0      -19110
# 4                4  5008809             0          270000.0      -19110
# ...            ...      ...           ...               ...         ...
# 438552      438552  6840104             0          135000.0      -22717
# 438553      438553  6840222             0          103500.0      -15939
# 438554      438554  6841878             0           54000.0       -8169
# 438555      438555  6842765             0           72000.0      -21673
# 438556      438556  6842885             0          121500.0      -18858
#
#         DAYS_EMPLOYED  FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL  \
# ...

# %%
cc = pd.read_csv('credit_record.csv')

# %%
cc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 3 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   ID              1048575 non-null  int64
#  1   MONTHS_BALANCE  1048575 non-null  int64
#  2   STATUS          1048575 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 24.0+ MB

# %%
zeroes = cc.loc[cc["STATUS"] == '0', :]

# %%
zeroes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 383120 entries, 1 to 1048544
# Data columns (total 3 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   ID              383120 non-null  int64
#  1   MONTHS_BALANCE  383120 non-null  int64
#  2   STATUS          383120 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 11.7+ MB

# %%
cc.count()
# Out:
# ID                1048575
# MONTHS_BALANCE    1048575
# STATUS            1048575
# dtype: int64

# %%
df.dropna()
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 2       5008806           M            Y               Y             0
# 3       5008808           F            N               Y             0
# 4       5008809           F            N               Y             0
# 5       5008810           F            N               Y             0
# 6       5008811           F            N               Y             0
# ...         ...         ...          ...             ...           ...
# 438541  6837707           M            N               Y             0
# 438548  6839936           M            Y               Y             1
# 438553  6840222           F            N               N             0
# 438554  6841878           F            N               N             0
# 438556  6842885           F            N               Y             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
cc['ID'].nunique()
# Out:
# 45985
